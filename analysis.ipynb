# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Задача - проверить взаимосвязь данных между регионом и победой определенной стороны (тьма/свет)

df = pd.read_csv("Data/match.csv")

print(f'Head: {df.head()}\n\n')
print(f'Info: {df.info()}')
print(f'IsNull: {df.isnull().sum}')

# Если есть пустое значение в этой колонне, мы просто удалим строку
df = df['radiant_win'].dropna()

# df = df.fillna(df.mean()) заполним просто пустые данные, как альтернатива


# Сначала обработаем данные, посмотрим вбросы, нулевые значения и исправим
# Out:
# Head:    match_id  start_time  duration  tower_status_radiant  tower_status_dire
# 0         0  1446750112      2375                  1982                  4  \
# 1         1  1446753078      2582                     0               1846
# 2         2  1446764586      2716                   256               1972
# 3         3  1446765723      3085                     4               1924
# 4         4  1446796385      1887                  2047                  0
#
#    barracks_status_dire  barracks_status_radiant  first_blood_time  game_mode
# 0                     3                       63                 1         22  \
# 1                    63                        0               221         22
# 2                    63                       48               190         22
# 3                    51                        3                40         22
# 4                     0                       63                58         22
#
# ...
